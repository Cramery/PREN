# %% [markdown]
# <b>Image Detection Playground PREN Team 4</b>
# <br>Readme lesen!</br>

# %%
from IPython.display import Image
from matplotlib import pyplot as plt
import numpy as np
import cv2
import timeit

#Timeit als alias hinzugefügt, siehe Link weiter unten
# %alias_magic t timeit
# Out:
# Created `%t` as an alias for `%timeit`.
# Created `%%t` as an alias for `%%timeit`.

# %%
#Siehe Folder Images
Image('./Images/H1.jpeg')

# %%
def demoImage():
    img = cv2.imread('Images//H1.jpeg')
    #Mathplotlib erwartet RGB, siehe: https://gist.github.com/mstfldmr/45d6e47bb661800b982c39d30215bc88
    rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    plt.imshow(rgb)
    plt.title('demo pic')
    plt.show()

demoImage()

# %% [markdown]
# Measurement mit <b>timeit</b> gemacht, siehe: http://ipython.org/ipython-doc/dev/interactive/magics.html#magic-timeit <br>
# Plotting entfernt, da er jedes einzelne Bild aufgeplottet hätte.

# %%
def demoPerformance():
    img = cv2.imread('Images//H1.jpeg')
    rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

#timeit aufruf von demoPerformancemethode
# %t -n5 demoPerformance()
# Out:
# 38.5 ms ± 656 µs per loop (mean ± std. dev. of 7 runs, 5 loops each)
